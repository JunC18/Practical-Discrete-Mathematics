# %% [markdown]
# <a href="https://colab.research.google.com/github/JunC18/Practical-Discrete-Mathematics/blob/master/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 6 - Computational Algorithms in Linear Algebra
#
# This notebook contains code accompanying Chapter 6 Computational Algorithms in Linear Algebra in *Practical Discrete Mathematics* by Ryan T. White and Archana Tikayat Ray.
#
# ## Matrices and Matrix Representations of Linear Systems
#
# The code below stores matrices as `NumPy` arrays and prints specified entries of the matrices.

# %%
import numpy

# initialize matrices
A = numpy.array([[3, 2, 1], [9, 0, 1], [3, 4, 1]])
B = numpy.array([[1, 1, 2], [8, 4, 1], [0, 0, 3]])

# print the entry in the first row and first column of A
print(A[0,0])

# print the entry in the second row and third column of B
print(B[1,2])
# Out:
# 3
# 1

# %% [markdown]
# ### Example: Matrix Addition and Subtraction

# %%
# Add A and B
print(numpy.add(A,B))

# Subtract A and B
print(numpy.subtract(A,B))
# Out:
# [[ 4  3  3]
#  [17  4  2]
#  [ 3  4  4]]
# [[ 2  1 -1]
#  [ 1 -4  0]
#  [ 3  4 -2]]

# %% [markdown]
# ### Example: Scalar Multiplication and Transpose

# %%
# Multiply A by a scalar 5
print(numpy.multiply(5,A))

# Find the transpose of A
print(numpy.transpose(A))
# Out:
# [[15 10  5]
#  [45  0  5]
#  [15 20  5]]
# [[3 9 3]
#  [2 0 4]
#  [1 1 1]]

# %% [markdown]
# ### Example: Matrix Multiplication and Transpose

# %%
# Multiply A and B
print(numpy.dot(A,B))
# Out:
# [[19 11 11]
#  [ 9  9 21]
#  [35 19 13]]

# %% [markdown]
# ## Solving Large Linear Systems with `NumPy`
#
# ### Example: Solving $\mathbf{Ax}=\mathbf{b}$ for $\mathbf{x}$

# %%
import numpy

# Create A and b matrices
A = numpy.array([[2, -6, 6], [2, 3, -1], [4, -3, -1]])
b = numpy.array([-8, 15, 19])

# Solve Ax = b
numpy.linalg.solve(A,b)
# Out:
# array([ 5.,  1., -2.])

# %% [markdown]
# ### Example: Inconsistent and Dependent Systems with `NumPy`

# %%
import numpy

# inconsistent system
A = numpy.array([[2, 1], [6, 3]])
b = numpy.array([3, 3])

print(numpy.linalg.solve(A,b))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-14-88a6688b74fc> in <module>
#       5 b = numpy.array([3, 3])
#       6
# ----> 7 print(numpy.linalg.solve(A,b))
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# Note that the code throws an error because the matrix $\mathbf{A}$ is singular since the system is inconsistent--i.e. there are no solutions.

# %%
# dependent system
A = numpy.array([[2, 1], [6, 3]])
b = numpy.array([1, 3])

print(numpy.linalg.solve(A,b))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-19-a7825dde56f3> in <module>
#       3 b = numpy.array([1, 3])
#       4
# ----> 5 print(numpy.linalg.solve(A,b))
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# Note that the code throws an error because the matrix $\mathbf{A}$ is singular since the system is dependent--i.e. there are infinitely many solutions, as we can confirm below.

# %%
A = numpy.array([[2, 1], [6, 3]])
print(numpy.linalg.det(A))
# Out:
# 0.0

# %% [markdown]
# ### Example: 10-by-10 Linear System (with `NumPy`)

# %%
import numpy

numpy.random.seed(1)

# Create A and b matrices with random
A = 10*numpy.random.rand(10,10)-5
b = 10*numpy.random.rand(10)-5

# Solve Ax = b
solution = numpy.linalg.solve(A,b)
print(solution)

# To verify the solution works, show Ax - b is near 0
sum(abs(numpy.dot(A,solution) - b))
# Out:
# [ 0.09118027 -1.51451319 -2.48186344 -2.94076307  0.07912968  2.76425416
#   2.48851394 -0.30974375 -1.97943716  0.75619575]
# 2.1538326677728037e-14

# %% [markdown]
# ### Write python code in Google Colab for the following. You are allowed to use any GenAl to guide you.
#
#
# 1. Load any creative common image from wikipedia. Enlarge the image double of its size.
# 2. Transpose the image 90 degree
# 3. Change the image colour to gray tone.

# %%
# Import necessary libraries
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# URL of the Creative Commons image from Wikipedia
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Bugatti_Chiron_1.jpg/420px-Bugatti_Chiron_1.jpg"

# Fetch the image
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Display the original image
plt.figure(figsize=(6, 6))
plt.title("Original Image")
plt.imshow(img)
plt.axis('off')
plt.show()

# Enlarge the image by a factor of 2
width, height = img.size
new_size = (int(width * 2), int(height * 2))
enlarged_img = img.resize(new_size, Image.LANCZOS)

# Display the enlarged image
plt.figure(figsize=(12, 12))
plt.title("Enlarged Image")
plt.imshow(enlarged_img)
plt.axis('off')
plt.show()

# %%
# Import necessary libraries
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# URL of the Creative Commons image from Wikipedia
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Bugatti_Chiron_1.jpg/420px-Bugatti_Chiron_1.jpg"

# Fetch the image
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Display the original image
plt.figure(figsize=(6, 6))
plt.title("Original Image")
plt.imshow(img)
plt.axis('off')
plt.show()

# Transpose the image by 90 degrees
transposed_img = img.transpose(Image.ROTATE_90)

# Display the transposed image
plt.figure(figsize=(6, 6))
plt.title("Transposed Image")
plt.imshow(transposed_img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Find 2 creative common images online. Combine these 2 images side by side vertically. Export it as Jpg Change the image colour to gray tone.

# %%
# !pip install opencv-python-headless # installing opencv library

import cv2
import requests
from io import BytesIO
import numpy as np

# Load the image from the URL
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Bugatti_Chiron_1.jpg/420px-Bugatti_Chiron_1.jpg"
response = requests.get(url)
image = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_UNCHANGED)

# Background removal using OpenCV (simple thresholding for this example)
# This approach might need adjustments based on the image content.

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Threshold the image to create a mask
_, mask = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Apply the mask to extract the foreground (character)
foreground = cv2.bitwise_and(image, image, mask=mask)

# Display the image
# (In Colab, you'll see the output directly)
from google.colab.patches import cv2_imshow
cv2_imshow(foreground) # Display the foreground
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.26.4)
# <PIL.Image.Image image mode=RGB size=420x224>
